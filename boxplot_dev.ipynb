# %%
import matplotlib.pyplot as plt
import sciplots02 as box
import numpy as np

# %%
testdata = {
    f"t{n}": np.random.randint(-100,100,size=100) for n in range(20)
}

fig = plt.figure(dpi=150,figsize=(8,5))
ax = fig.add_subplot()
plot = box.Boxplot(
    testdata,ax,
    groups={"test1":["t2","t3","t4"],"test3":["t10","t11","t12"],"test2":["t5","t7","t8"]},
    color=[(0,0,0),(.2,.2,.2),(.5,.5,.5)],
    legend={"bla":(0,0,0)},
    compare=[["t2","t3"]]
)
plt.show()
# Out:
# PathPatch6((0.6, -55.25) ...)
# PathPatch6((0.9, -53) ...)
# c:\Users\Sasch\Documents\Code\Decentplots\sciplots02.py:158: UserWarning: FixedFormatter should only be used together with FixedLocator
#   self.ax.set_yticklabels(self.ax.get_yticklabels(), fontsize=self.kwargs["tickFontsize"])

# %%
for i,whisker in enumerate(plot.artist["whiskers"]):
    if i%2: print(whisker.get_path().get_extents().y1,"\n")
# Out:
# 98.0
#
# 96.0
#
# 93.0
#
# 98.0
#
# 98.0
#
# 99.0
#
# 95.0
#
# 98.0
#
# 99.0

# %%
[whisker.get_path().get_extents().y1 for i,whisker in enumerate(plot.artist["whiskers"]) if i%2]
# Out:
# [98.0, 96.0, 93.0, 98.0, 98.0, 99.0, 95.0, 98.0, 99.0]
