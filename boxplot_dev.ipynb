# %%
import matplotlib.pyplot as plt
import sciplots02 as box
import numpy as np

# %%
testdata = {
    f"t{n}": np.random.randint(-100,100,size=100) for n in range(20)
}

fig = plt.figure(dpi=150,figsize=(8,5))
ax = fig.add_subplot()
plot = box.Boxplot(
    testdata,ax,
    groups={"test1":["t2","t3","t4"],"test3":["t10","t11","t12"],"test2":["t5","t7","t8"]},
    color=[(0,0,0),(.2,.2,.2),(.5,.5,.5)],
    legend={"bla":(0,0,0)},
    compare=[["t2","t3"]]
)
plt.show()
# Out:
# c:\Users\Sasch\Documents\Code\Decentplots\sciplots02.py:185: UserWarning: FixedFormatter should only be used together with FixedLocator
#   self.ax.set_yticklabels(self.ax.get_yticklabels(), fontsize=self.kwargs["tickFontsize"])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plot.dataRange
#
# AttributeError: 'Boxplot' object has no attribute 'dataRange'
